# %% [markdown]
# ### Correlation heat map between the attributes

# %% [markdown]
# ###### We can clearly see that the dataset has very less values for one class, which could lead to a Model with unbalanced data

# %% [markdown]
# ### Data distribution by attribute

# %%
fig, axarr = plt.subplots(3, 3, figsize=(25, 15))
sns.countplot(x='Gender', hue = 'Label',data = df, ax=axarr[0][0])
sns.countplot(x='Dependent_count', hue = 'Label',data = df, ax=axarr[0][1])
sns.countplot(x='Education_Level', hue = 'Label',data = df, ax=axarr[0][2])
sns.countplot(x='Marital_Status', hue = 'Label',data = df, ax=axarr[1][0])
sns.countplot(x='Income_Category', hue = 'Label',data = df, ax=axarr[1][1])
sns.countplot(x='Card_Category', hue = 'Label',data = df, ax=axarr[1][2])
sns.countplot(x='Months_Inactive_12_mon', hue = 'Label',data = df, ax=axarr[2][0]);

# %% [markdown]
# ## Epoch - Error curve

# %%
plt.plot(history.history['loss'], label='Training error')
plt.plot(history.history['val_loss'], label = 'Validation error', )
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.tight_layout()


plt.show();

# %% [markdown]
# ## Contingency matrix for ANN

# %% [markdown]
# ## ROC Curve

# %% [markdown]
# ## Performance measures

# %%
# Out:
# Text(0.5, 1.0, 'Bankchurn_ANN')
